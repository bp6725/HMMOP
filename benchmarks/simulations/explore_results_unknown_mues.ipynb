# %% [markdown]
# # Init

# %%
import sys
sys.path.append(r"../../../pomegranate")
sys.path.append(r"../../../WhoCell/")
sys.path.append(r"../../../WhoCell/who_cell/")
sys.path.append(r"../../../WhoCell/who_cell/models/")
sys.path.append(r"../../../WhoCell/who_cell/simulation/")

# %%
from functools import reduce
from collections import Counter
import seaborn as sns

# %%
import pomegranate
from pomegranate import *
import numpy as np
import math 
import matplotlib.pyplot as plt
from functools import partial 
import itertools
import random
import copy
import pandas as pd
import itertools
import networkx as nx
import holoviews as hv
from IPython.display import display, HTML,clear_output
from scipy.stats import binom
from ast import literal_eval as make_tuple


from numba import jit
import numba

from gibbs_sampler import GibbsSampler
from simulation_for_gibbs import Simulator_for_Gibbs
from who_cell.experiments.experiment_report import ExperimentReport
from who_cell.experiments.gibbs_experiments import GibbsExperiment



from tqdm import tqdm
import snakeviz
# %load_ext snakeviz
# %load_ext autoreload
hv.extension('bokeh', config=dict(future_deprecations=True))
# Out:
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# %connect_info
# Out:
# {
#   "shell_port": 38879,
#   "iopub_port": 58741,
#   "stdin_port": 33983,
#   "control_port": 49205,
#   "hb_port": 32927,
#   "ip": "127.0.0.1",
#   "key": "7eb81890-67ef47a55ea59fd08abfeb7a",
#   "transport": "tcp",
#   "signature_scheme": "hmac-sha256",
#   "kernel_name": ""
# }
#
# Paste the above JSON into a file, and connect with:
#     $> jupyter <app> --existing <file>
# or, if you are local, you can connect with just:
#     $> jupyter <app> --existing kernel-dba19ef9-5805-4649-bed2-6d73e2356710.json
# or even just:
#     $> jupyter <app> --existing
# if this is the most recent Jupyter kernel you have started.

# %% [markdown]
# # run

# %%
model_defining_params_pre = ['N', "d", "n_states",'is_acyclic','sigma','bipartite']
params_dict = {
    'is_acyclic': [True],
    'known_mues' : [True],
    "is_few_observation_model":[True,False],
    "is_only_seen" : [True,False],
    'N': [50],
    'd': [9],
    "bipartite":[True,False],
    "inner_outer_trans_probs_ratio":[50],
    'n_states': [10],
    'sigma' : [0.1],
    'number_of_smapled_traj': [10000],
    'p_prob_of_observation': [0.2,0.5],
    'N_itres': [100],
    'is_mh':[False],
    'w_smapler_n_iter': [10]}

# %%
er = ExperimentReport()
all_models_results = GibbsExperiment.run_multi_params_and_return_results(params_dict,model_defining_params_pre,skip_sampler=False)
# Out:
# {'is_few_observation_model': True, 'is_only_seen': True, 'p_prob_of_observation': 0.2, 'is_acyclic': True, 'known_mues': True, 'N': 50, 'd': 9, 'bipartite': True, 'inner_outer_trans_probs_ratio': 50, 'n_states': 10, 'sigma': 0.1, 'number_of_smapled_traj': 10000, 'N_itres': 100, 'is_mh': False, 'w_smapler_n_iter': 10}
# 100%|█████████████████████████████████████████| 100/100 [54:44<00:00, 32.85s/it]
# finish
# /home/benny/Repos/Few_observations_hmm/WhoCell/benchmarks/simulations/../../../WhoCell/who_cell/simulation/simulation_for_gibbs.py:56: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   long_sampled = pome_model.sample(length =traj_length
# ...

# %% [markdown]
# # plot results

# %%
def rebuild_transitions_dict(transitions,all_states) : 
    new_transitions = {str(k):{str(kk):vv for kk,vv in v.items()} for k,v in transitions.items()}
    
    for state in all_states : 
        for k,v in transitions.items():
            if state not in new_transitions[str(k)].keys() :
                new_transitions[str(k)][state] = 0
    return new_transitions

# %%
def plot_results(transitions_results_list,experiments_name_list,transitions_probs,title):
    er = ExperimentReport()

    __l1_distance = lambda dist,state,known : abs(dist[state]-known) if state in dist.keys() else known
    __cross_entropy_distance = lambda dist,state,known : -1*known*np.log(dist[state]) if state in dist.keys() else (-1*known*np.log(0.0001))

    _l1_distance = lambda known_dist,comp_dist:sum(([__l1_distance(comp_dist,state,prob) for state,prob in known_dist.items()]))
    _cross_entropy_distance = lambda known_dist,comp_dist:sum([__cross_entropy_distance(comp_dist,state,prob) for state,prob in known_dist.items()])

    l1_distance = lambda known_trns,comp_trans : np.mean([_l1_distance(dist,comp_trans[state]) for state,dist in known_trns.items()])
    cross_entropy_distance = lambda known_trns,comp_trans : np.mean([_cross_entropy_distance(dist,comp_trans[state]) for state,dist in known_trns.items()])

    _trajectory_prob = lambda traj,model_trans:reduce(lambda x,y:x*y,[(model_trans[_f][_t] if _t in model_trans[_f].keys() else 0) for _f,_t in zip(traj,traj[1:])])


    all_l1_results = {}
    all_ce_results = {}
    for _trans_list,exp_name in zip(transitions_results_list,experiments_name_list) : 
        l1_dist = [l1_distance(transitions_probs,_t) for _t in _trans_list]
        ce_dist = [cross_entropy_distance(transitions_probs,_t) for _t in _trans_list]

        all_l1_results[exp_name] = l1_dist
        all_ce_results[exp_name] = ce_dist



#     for all_results,name in zip([all_l1_results,all_ce_results],['l1','crossEntropy']) : 
    for all_results,name in zip([all_l1_results],['l1']) : 
        fig, sub = plt.subplots(1,1,figsize=(8, 8))
        fig.suptitle(title)
        model_results_df = pd.DataFrame(all_results)

        sns.lineplot(data=model_results_df, ax=sub, legend='full', dashes=False)
        sub.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
        sub.set_title(f"{name}")
        sub.set_xlabel("iter")
        sub.set_ylabel(f"{name}")

        plt.subplots_adjust(hspace=0.8)
        plt.subplots_adjust(wspace=0.8)

        plt.show()

# %%
for mutual_model_idx,mutual_model in all_models_results.items() : 
    transitions_results_list = [] 
    experiments_name_list = []
    for unique_model_id,unique_model in mutual_model.items():
        all_states = list(unique_model["start_probabilites"].keys())
        _transitions = list(map(lambda x:rebuild_transitions_dict(x,all_states),unique_model['all_transitions']))
        _experiment_name = ";".join(map(lambda x:f"{x[0]}:{x[1]}",unique_model['hyper_params'].items()))
        
        transitions_results_list.append(_transitions)
        experiments_name_list.append(_experiment_name)
    transitions_probs = rebuild_transitions_dict(er._extrect_states_transitions_dict_from_pome_model(unique_model['original_pome_model'])[0],all_states)
    title = ";".join(map(lambda x:f"{x[0]}:{x[1]}",unique_model['mutual_params'].items()))
    plot_results(transitions_results_list,experiments_name_list,transitions_probs,title)

# %%
for mutual_model_idx,mutual_model in all_models_results.items() : 
    transitions_results_list = [] 
    experiments_name_list = []
    for unique_model_id,unique_model in mutual_model.items():
        if unique_model['hyper_params']['p_prob_of_observation'] == 0.2 : continue
        all_states = list(unique_model["start_probabilites"].keys())
        _transitions = list(map(lambda x:rebuild_transitions_dict(x,all_states),unique_model['all_transitions']))
        _experiment_name = ";".join(map(lambda x:f"{x[0]}:{x[1]}",unique_model['hyper_params'].items()))
        
        transitions_results_list.append(_transitions)
        experiments_name_list.append(_experiment_name)
    transitions_probs = rebuild_transitions_dict(er._extrect_states_transitions_dict_from_pome_model(unique_model['original_pome_model'])[0],all_states)
    title = ";".join(map(lambda x:f"{x[0]}:{x[1]}",unique_model['mutual_params'].items()))
    plot_results(transitions_results_list,experiments_name_list,transitions_probs,title)

# %%
for mutual_model_idx,mutual_model in all_models_results.items() : 
    transitions_results_list = [] 
    experiments_name_list = []
    for unique_model_id,unique_model in mutual_model.items():
        if unique_model['hyper_params']['p_prob_of_observation'] == 0.5 : continue
        all_states = list(unique_model["start_probabilites"].keys())
        _transitions = list(map(lambda x:rebuild_transitions_dict(x,all_states),unique_model['all_transitions']))
        _experiment_name = ";".join(map(lambda x:f"{x[0]}:{x[1]}",unique_model['hyper_params'].items()))
        
        transitions_results_list.append(_transitions)
        experiments_name_list.append(_experiment_name)
    transitions_probs = rebuild_transitions_dict(er._extrect_states_transitions_dict_from_pome_model(unique_model['original_pome_model'])[0],all_states)
    title = ";".join(map(lambda x:f"{x[0]}:{x[1]}",unique_model['mutual_params'].items()))
    plot_results(transitions_results_list,experiments_name_list,transitions_probs,title)

# %%
sns.clustermap(pd.DataFrame(transitions_probs))

# %%
unique_model["start_probabilites"]
# Out:
# {'(1, 0.1)': 0.1,
#  '(2, 0.1)': 0.1,
#  '(3, 0.1)': 0.1,
#  '(4, 0.1)': 0.1,
#  '(5, 0.1)': 0.1,
#  '(6, 0.1)': 0.1,
#  '(7, 0.1)': 0.1,
#  '(8, 0.1)': 0.1,
#  '(9, 0.1)': 0.1,
#  '(10, 0.1)': 0.1}
