# %% [markdown]
# # Init

# %%
import pandas  as pd
import pickle
import matplotlib.pyplot
import sys
import numpy as np
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
import matplotlib.pyplot as plt
from functools import reduce
from tqdm import tqdm
import  snakeviz
import seaborn as sns


import itertools
sys.path.append('C:\Repos\WhoCell\who_cell')
sys.path.append('C:\Repos\WhoCell')
sys.path.append('C:\Repos\WhoCell\who_cell\experiments')
sys.path.append('C:/Repos/WhoCell/who_cell/models')
sys.path.append('C:\Repos\pomegranate')

from pomegranate import *
import transitions_dict
import who_cell
from gibbs_experiments import GibbsExperiment
from gibbs_sampler import GibbsSampler
from who_cell.experiments.experiment_report import ExperimentReport

# %% [markdown]
# # runs - 01062021

# %%
model_defining_params_pre = ['N', "d", "n_states",'is_acyclic']
params_dict = {
    'is_acyclic': [True,False],
    'N': [20,80],
    'd': [5],
    'n_states': [10],
    'number_of_smapled_traj': [300,100],
    'p_prob_of_observation': [0.4,0.7, 1],
    'N_itres': [20],
    'w_smapler_n_iter': [20]}

GibbsExperiment.run_multi_params_and_plot_report(params_dict,model_defining_params_pre)
# Out:
# ...
#   0%|                                                                                           | 0/24 [00:00<?, ?it/s]
# finish solving
# 100%|███████████████████████████████████████████████████████████████████████████████| 24/24 [6:13:11<00:00, 932.98s/it]
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-bda797a6c40a> in <module>()
#      10     'w_smapler_n_iter': [20]}
#      11
# ---> 12 GibbsExperiment.run_multi_params_and_plot_report(params_dict,model_defining_params_pre)
#
# C:\Repos\WhoCell\who_cell\experiments\gibbs_experiments.py in run_multi_params_and_plot_report(params_dict, model_defining_params_pre, params_titles, mutual_model_params_titles)
# ...

# %%
model_defining_params_pre = ['N', "d", "n_states",'is_acyclic']
params_dict = {
    'is_acyclic': [True,False],
    'N': [8],
    'd': [5],
    'n_states': [10],
    'number_of_smapled_traj': [600,300],
    'p_prob_of_observation': [0.4,0.7, 1],
    'N_itres': [50],
    'w_smapler_n_iter': [20]}

GibbsExperiment.run_multi_params_and_plot_report(params_dict,model_defining_params_pre)
# Out:
# ...
#   0%|                                                                                           | 0/12 [00:00<?, ?it/s]
# finish solving
# 100%|███████████████████████████████████████████████████████████████████████████████| 12/12 [1:21:13<00:00, 406.09s/it]
# stop
# stop
# stop
# stop
# stop
# stop
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-3f3a0848f1da> in <module>()
#      10     'w_smapler_n_iter': [20]}
#      11
# ---> 12 GibbsExperiment.run_multi_params_and_plot_report(params_dict,model_defining_params_pre)
#
# C:\Repos\WhoCell\who_cell\experiments\gibbs_experiments.py in run_multi_params_and_plot_report(params_dict, model_defining_params_pre, params_titles, mutual_model_params_titles)
#     115         all_models_results = GibbsExperiment.run_multi_params_and_return_results(params_dict,model_defining_params_pre)
#     116
# ...
